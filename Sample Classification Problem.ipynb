# %%
from PIL import Image
img = Image.open('Assignment-7 Q.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1390x342 at 0x14F851F9CD0>

# %%
from PIL import Image
img = Image.open('AI Assignment - 7.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1325x1910 at 0x14F851F9E20>
